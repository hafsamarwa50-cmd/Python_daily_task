# %% [markdown]
# # SINGLE LEVEL INHERITANCE:

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age


class Student(Person):
    def __init__(self, name, age, marks):
        super().__init__(name, age)
        self.marks = marks

    def display(self):
        print("Name:", self.name)
        print("Age:", self.age)
        print("Marks:", self.marks)


s = Student("Rahul", 20, 85)
s.display()
# Out:
# Name: Rahul
# Age: 20
# Marks: 85

# %%
class Vehicle:
    def start(self):
        print("Vehicle is starting")


class Car(Vehicle):
    def __init__(self, brand):
        self.brand = brand

    def start(self):
        print(self.brand, "car starts with a key")


c = Car("Toyota")
c.start()
# Out:
# Toyota car starts with a key

# %%
class Animal:
    def eat(self):
        print("Animal is eating")


class Dog(Animal):
    def bark(self):
        print("Dog is barking")


d = Dog()
d.eat()
d.bark()
# Out:
# Animal is eating
# Dog is barking

# %%
class Employee:
    def __init__(self, emp_id, salary):
        self.emp_id = emp_id
        self.salary = salary


class Manager(Employee):
    def __init__(self, emp_id, salary, department):
        super().__init__(emp_id, salary)
        self.department = department

    def display(self):
        print("Employee ID:", self.emp_id)
        print("Salary:", self.salary)
        print("Department:", self.department)


m = Manager(101, 50000, "HR")
m.display()
# Out:
# Employee ID: 101
# Salary: 50000
# Department: HR

# %%
class Shape:
    def area(self):
        print("Area of shape")


class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        print("Area =", 3.14 * self.radius * self.radius)


c = Circle(5)
c.area()
# Out:
# Area = 78.5

# %%
class BankAccount:
    def __init__(self, balance):
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print("Balance:", self.balance)

    def withdraw(self, amount):
        self.balance -= amount
        print("Balance:", self.balance)


class SavingsAccount(BankAccount):
    def calculate_interest(self):
        interest = self.balance * 0.05
        print("Interest:", interest)


s = SavingsAccount(10000)
s.deposit(2000)
s.withdraw(1000)
s.calculate_interest()
# Out:
# Balance: 12000
# Balance: 11000
# Interest: 550.0

# %%
class Product:
    def __init__(self, price):
        self.price = price

    def discount(self):
        print("Discounted Price:", self.price * 0.9)


class Electronics(Product):
    def __init__(self, price, warranty):
        super().__init__(price)
        self.warranty = warranty

    def display(self):
        print("Price:", self.price)
        print("Warranty:", self.warranty)
        self.discount()


e = Electronics(50000, "2 Years")
e.display()
# Out:
# Price: 50000
# Warranty: 2 Years
# Discounted Price: 45000.0

# %%
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author


class TextBook(Book):
    def __init__(self, title, author, subject):
        super().__init__(title, author)
        self.subject = subject

    def display(self):
        print("Title:", self.title)
        print("Author:", self.author)
        print("Subject:", self.subject)


b = TextBook("Python", "Sumit", "Programming")
b.display()
# Out:
# Title: Python
# Author: Sumit
# Subject: Programming

# %%
class Device:
    def turn_on(self):
        print("Device is ON")


class Mobile(Device):
    def call(self, number):
        print("Calling", number)


m = Mobile()
m.turn_on()
m.call("9876543210")
# Out:
# Device is ON
# Calling 9876543210

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age


class Teacher(Person):
    def __init__(self, name, age, subject):
        super().__init__(name, age)
        self.subject = subject

    def display(self):
        print("Name:", self.name)
        print("Age:", self.age)
        print("Subject:", self.subject)


t = Teacher("Anita", 35, "Math")
t.display()
# Out:
# Name: Anita
# Age: 35
# Subject: Math

# %%
class Sports:
    def play(self):
        print("Playing sports")


class Cricket(Sports):
    def play(self):
        print("Playing Cricket")


c = Cricket()
c.play()
# Out:
# Playing Cricket

# %%
class Account:
    def __init__(self, balance):
        self.balance = balance


class LoanAccount(Account):
    def calculate_emi(self):
        emi = self.balance / 12
        print("Monthly EMI:", emi)


l = LoanAccount(120000)
l.calculate_emi()
# Out:
# Monthly EMI: 10000.0

# %%
class Employee:
    def __init__(self, salary):
        self.salary = salary

    def get_salary(self):
        return self.salary


class Developer(Employee):
    def __init__(self, salary, bonus):
        super().__init__(salary)
        self.bonus = bonus

    def display(self):
        total = self.get_salary() + self.bonus
        print("Total Salary:", total)


d = Developer(50000, 10000)
d.display()
# Out:
# Total Salary: 60000

# %%
class Animal:
    def move(self):
        print("Animal moves")


class Bird(Animal):
    def move(self):
        print("Bird flies")


b = Bird()
b.move()
# Out:
# Bird flies

# %%
class Vehicle:
    def __init__(self, fuel_type):
        self.fuel_type = fuel_type

    def display(self):
        print("Fuel Type:", self.fuel_type)


class ElectricVehicle(Vehicle):
    def __init__(self):
        super().__init__("Electric")

    def display(self):
        print("This is an Electric Vehicle")
        print("Fuel Type:", self.fuel_type)


e = ElectricVehicle()
e.display()
# Out:
# This is an Electric Vehicle
# Fuel Type: Electric

# %% [markdown]
# # MULTI -LEVEL INHERITANCE:

# %%
class Person:
    def __init__(self, name):
        self.name = name


class Employee(Person):
    def __init__(self, name, employee_id):
        super().__init__(name)
        self.employee_id = employee_id


class Manager(Employee):
    def __init__(self, name, employee_id, department):
        super().__init__(name, employee_id)
        self.department = department

    def display(self):
        print("Name:", self.name)
        print("Employee ID:", self.employee_id)
        print("Department:", self.department)


m = Manager("Rahul", 101, "HR")
m.display()
# Out:
# Name: Rahul
# Employee ID: 101
# Department: HR

# %%
class Animal:
    def eat(self):
        print("Animal is eating")


class Mammal(Animal):
    def walk(self):
        print("Mammal is walking")


class Dog(Mammal):
    def bark(self):
        print("Dog is barking")


d = Dog()
d.eat()
d.walk()
d.bark()
# Out:
# Animal is eating
# Mammal is walking
# Dog is barking

# %%
class Vehicle:
    def start(self):
        print("Vehicle starts")


class Car(Vehicle):
    def start(self):
        print("Car starts with a key")


class SportsCar(Car):
    def start(self):
        print("Sports Car starts with push button")


s = SportsCar()
s.start()
# Out:
# Sports Car starts with push button

# %%
class Shape:
    pass


class Polygon(Shape):
    pass


class Rectangle(Polygon):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        print("Area =", self.length * self.width)


r = Rectangle(10, 5)
r.area()
# Out:
# Area = 50

# %%
class BankAccount:
    def __init__(self, balance):
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print("Balance:", self.balance)


class SavingsAccount(BankAccount):
    def calculate_interest(self):
        print("Interest:", self.balance * 0.05)


class RecurringDeposit(SavingsAccount):
    def maturity(self, years):
        amount = self.balance + (self.balance * 0.05 * years)
        print("Maturity Amount:", amount)


r = RecurringDeposit(10000)
r.deposit(2000)
r.calculate_interest()
r.maturity(2)
# Out:
# Balance: 12000
# Interest: 600.0
# Maturity Amount: 13200.0

# %%
class Employee:
    def __init__(self, name):
        self.name = name


class ITEmployee(Employee):
    def __init__(self, name, department):
        super().__init__(name)
        self.department = department


class SoftwareEngineer(ITEmployee):
    def __init__(self, name, department, programming_skills):
        super().__init__(name, department)
        self.programming_skills = programming_skills

    def display(self):
        print("Name:", self.name)
        print("Department:", self.department)
        print("Skills:", self.programming_skills)


s = SoftwareEngineer("Anita", "IT", "Python")
s.display()
# Out:
# Name: Anita
# Department: IT
# Skills: Python

# %%
class Product:
    def __init__(self, name, price):
        self.name = name
        self.price = price


class Electronics(Product):
    def __init__(self, name, price, warranty):
        super().__init__(name, price)
        self.warranty = warranty


class Smartphone(Electronics):
    def __init__(self, name, price, warranty, ram, storage):
        super().__init__(name, price, warranty)
        self.ram = ram
        self.storage = storage

    def display(self):
        print("Name:", self.name)
        print("Price:", self.price)
        print("Warranty:", self.warranty)
        print("RAM:", self.ram)
        print("Storage:", self.storage)


p = Smartphone("Samsung", 45000, "2 Years", "8GB", "128GB")
p.display()
# Out:
# Name: Samsung
# Price: 45000
# Warranty: 2 Years
# RAM: 8GB
# Storage: 128GB

# %%
class LivingBeing:
    def move(self):
        print("Living Being moves")


class Animal(LivingBeing):
    def move(self):
        print("Animal walks")


class Bird(Animal):
    def move(self):
        print("Bird flies")


b = Bird()
b.move()
# Out:
# Bird flies

# %%
class Person:
    def __init__(self, name):
        self.name = name


class Student(Person):
    def __init__(self, name, marks):
        super().__init__(name)
        self.marks = marks


class EngineeringStudent(Student):
    def __init__(self, name, marks, branch):
        super().__init__(name, marks)
        self.branch = branch

    def display(self):
        print("Name:", self.name)
        print("Marks:", self.marks)
        print("Branch:", self.branch)


e = EngineeringStudent("Priya", 92, "CSE")
e.display()
# Out:
# Name: Priya
# Marks: 92
# Branch: CSE

# %%
class Device:
    def __init__(self, brand):
        self.brand = brand


class Computer(Device):
    def __init__(self, brand, processor):
        super().__init__(brand)
        self.processor = processor


class Laptop(Computer):
    def __init__(self, brand, processor, battery, portability):
        super().__init__(brand, processor)
        self.battery = battery
        self.portability = portability

    def display(self):
        print("Brand:", self.brand)
        print("Processor:", self.processor)
        print("Battery:", self.battery)
        print("Portable:", self.portability)


l = Laptop("Dell", "Intel i7", "8 Hours", "Yes")
l.display()
# Out:
# Brand: Dell
# Processor: Intel i7
# Battery: 8 Hours
# Portable: Yes

# %%
class Account:
    def __init__(self, balance):
        self.balance = balance


class SavingAccount(Account):
    def interest(self):
        print("Interest:", self.balance * 0.05)


class SeniorCitizenAccount(SavingAccount):
    def interest(self):
        print("Senior Interest:", self.balance * 0.08)


s = SeniorCitizenAccount(100000)
s.interest()
# Out:
# Senior Interest: 8000.0

# %%
class Vehicle:
    def __init__(self, brand):
        self.brand = brand


class FourWheeler(Vehicle):
    def __init__(self, brand, wheels):
        super().__init__(brand)
        self.wheels = wheels


class SUV(FourWheeler):
    def __init__(self, brand, wheels, seating_capacity, features):
        super().__init__(brand, wheels)
        self.seating_capacity = seating_capacity
        self.features = features

    def display(self):
        print("Brand:", self.brand)
        print("Wheels:", self.wheels)
        print("Seating:", self.seating_capacity)
        print("Features:", self.features)


s = SUV("Mahindra", 4, 7, "Sunroof")
s.display()
# Out:
# Brand: Mahindra
# Wheels: 4
# Seating: 7
# Features: Sunroof

# %%
class Employee:
    def __init__(self, name):
        self.name = name


class Manager(Employee):
    def __init__(self, name, department):
        super().__init__(name)
        self.department = department


class ProjectManager(Manager):
    def __init__(self, name, department, team_size):
        super().__init__(name, department)
        self.team_size = team_size

    def manage_team(self):
        print(self.name, "is managing a team of", self.team_size, "members.")


p = ProjectManager("Ravi", "IT", 12)
p.manage_team()
# Out:
# Ravi is managing a team of 12 members.

# %%
import math

class Shape:
    pass


class TwoDShape(Shape):
    pass


class Triangle(TwoDShape):
    def __init__(self, side1, side2, side3):
        self.side1 = side1
        self.side2 = side2
        self.side3 = side3

    def area(self):
        s = (self.side1 + self.side2 + self.side3) / 2
        area = math.sqrt(s * (s - self.side1) * (s - self.side2) * (s - self.side3))
        print("Area:", area)


t = Triangle(3, 4, 5)
t.area()
# Out:
# Area: 6.0

# %%
class GrandParent:
    def grandparent_method(self):
        print("GrandParent Method")


class Parent(GrandParent):
    def parent_method(self):
        print("Parent Method")


class Child(Parent):
    def child_method(self):
        print("Child Method")


class GrandChild(Child):
    def grandchild_method(self):
        print("GrandChild Method")


g = GrandChild()

g.grandparent_method()
g.parent_method()
g.child_method()
g.grandchild_method()

print(GrandChild.mro())
# Out:
# GrandParent Method
# Parent Method
# Child Method
# GrandChild Method
# [<class '__main__.GrandChild'>, <class '__main__.Child'>, <class '__main__.Parent'>, <class '__main__.GrandParent'>, <class 'object'>]
