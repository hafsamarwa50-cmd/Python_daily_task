# %%
age = int(input("Enter age: "))
marks = int(input("Enter marks: "))

if age >= 18 and age <= 25 and marks >= 60:
    print("Eligible for Admission")
else:
    print("Not Eligible")
# Out:
# Enter age:  20
# Enter marks:  67
# Eligible for Admission

# %%
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "12345":
    print("Login Successful")
else:
    print("Login Failed")
# Out:
# Enter username:  admin
# Enter password:  12345
# Login Successful

# %%
num = int(input("Enter a number: "))

if num >= 50 and num <= 100 and not (num % 5 == 0):
    print("Condition Satisfied")
else:
    print("Condition Not Satisfied")
# Out:
# Enter a number:  69
# Condition Satisfied

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    print("Largest:", a)
elif b >= a and b >= c:
    print("Largest:", b)
else:
    print("Largest:", c)
# Out:
# Enter first number:  3
# Enter second number:  2
# Enter third number:  3
# Largest: 3

# %%
name = input("Enter your full name: ")

print("Uppercase:", name.upper())
print("Lowercase:", name.lower())
print("Length:", len(name))
print("First 3 Characters:", name[:3])
print("Last 3 Characters:", name[-3:])
# Out:
# Enter your full name:  sumit
# Uppercase: SUMIT
# Lowercase: sumit
# Length: 5
# First 3 Characters: sum
# Last 3 Characters: mit

# %%
sentence = input("Enter a sentence: ")

print("First 10 Characters:", sentence[:10])
print("Last 10 Characters:", sentence[-10:])
print("Index 5 to 15:", sentence[5:15])
print("Every 2nd Character:", sentence[::2])
# Out:
# Enter a sentence:  python is a good language
# First 10 Characters: python is
# Last 10 Characters: d language
# Index 5 to 15: n is a goo
# Every 2nd Character: pto sago agae

# %%
word = input("Enter a word: ")

if word == word[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Enter a word:  madam
# Palindrome

# %%
email = input("Enter email: ")

position = email.find("@")

username = email[:position]
domain = email[position + 1:]

print("Username:", username)
print("Domain:", domain)
# Out:
# Enter email:  md@gmail.com
# Username: md
# Domain: gmail.com

# %%
password = input("Enter password: ")

if len(password) >= 8 and ("@" in password or "#" in password):
    print("Strong Password")
else:
    print("Weak Password")
# Out:
# Enter password:  12345
# Weak Password

# %%
english = int(input("Enter English marks: "))
math = int(input("Enter Math marks: "))
science = int(input("Enter Science marks: "))

if english >= 40 and math >= 40 and science >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter English marks:  23
# Enter Math marks:  78
# Enter Science marks:  87
# Fail

# %%
num = int(input("Enter a number: "))

if num > 0 and num % 2 == 0:
    print("Positive and Even")
elif num < 0 or num % 2 != 0:
    print("Negative or Odd")
else:
    print("Neither Condition")
# Out:
# Enter a number:  6
# Positive and Even

# %%
city = input("Enter city name: ")

print("Reverse:", city[::-1])

count = 0

for ch in city.lower():
    if ch in "aeiou":
        count += 1

print("Number of Vowels:", count)

print("Without First and Last Character:", city[1:-1])
# Out:
# Enter city name:  hyderabad
# Reverse: dabaredyh
# Number of Vowels: 3
# Without First and Last Character: yderaba

# %%
mobile = input("Enter 10-digit mobile number: ")

print("Network Code:", mobile[:3])
print("Middle 3 Digits:", mobile[3:6])
print("Last 4 Digits:", mobile[-4:])
# Out:
# Enter 10-digit mobile number:  1234567895
# Network Code: 123
# Middle 3 Digits: 456
# Last 4 Digits: 7895
