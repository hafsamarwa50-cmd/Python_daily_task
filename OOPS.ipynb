# %%
# syntax class:

class Class_name:

    # constructor
    def_init_(self,args,arg):

       self.variable_name = args
       self.variable_name = args

     # method

        def method_name(self):
            # behaviour

# %%
# student class


class Students:

    def class_name(self,cls_name):
        print(f"Students class_name : {cls_name}")


# create the class object

std1 = Students()

# call the method

std1.class_name("NareshIT")
# Out:
# Students class_name : NareshIT

# %%
# without constructor

class Students:

    # instance method

    def student_info(self,name,roll_no,class_n):

        self.Name = name 
        self.Roll_number = roll_no
        self.Class_name = class_n


    # method 2:

    def display_information(self):

        print(f"Student Name : {self.Name}")
        print(f"Student Roll_no : {Roll_number}")
        print(f"Student Class Name : {self.Class_name}")


# create the class object

std1 =Students()

# call the methods 1:
std1.student_info("Sumit",4952,"Data science")

# call the method 2:
std1,display_information()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 31
#      28 std1.student_info("Sumit",4952,"Data science")
#      30 # call the method 2:
# ---> 31 std1,display_information()
#
# NameError: name 'display_information' is not defined
