# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/user/Downloads/Hotel_booking_dataset - Hotel_booking_dataset.csv")

df["Age"] = (
    df["Age"].astype(str)
    .str.extract(r"(\d+)", expand=False)
)

df["Age"] = pd.to_numeric(df["Age"], errors="coerce")

df.loc[(df["Age"] < 18) | (df["Age"] > 90), "Age"] = pd.NA

plt.figure(figsize=(8, 5))
plt.hist(df["Age"].dropna(), bins=10)
plt.xlabel("Age")
plt.ylabel("Number of Customers")
plt.title("Distribution of Customer Age")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/user/Downloads/Hotel_booking_dataset - Hotel_booking_dataset.csv")

df["Room Type"] = (
    df["Room Type"].astype(str)
    .str.strip()
    .str.lower()
    .replace({
        "delux": "Deluxe",
        "deluxe": "Deluxe",
        "standard": "Standard",
        "suite": "Suite",
        "exec": "Executive",
        "executive": "Executive"
    })
)

plt.figure(figsize=(8, 5))
sns.countplot(data=df, x="Room Type")
plt.xlabel("Room Type")
plt.ylabel("Number of Bookings")
plt.title("Number of Bookings by Room Type")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/user/Downloads/Hotel_booking_dataset - Hotel_booking_dataset.csv")

df["City"] = df["City"].astype(str).str.strip().str.title()

df["City"] = df["City"].replace({
    "Hydrabad": "Hyderabad",
    "Bangalore": "Bengaluru"
})

df["Final Amount"] = pd.to_numeric(
    df["Final Amount"],
    errors="coerce"
)

avg_amount = (
    df.groupby("City")["Final Amount"]
    .mean()
    .reset_index()
)

plt.figure(figsize=(10, 5))
sns.barplot(
    data=avg_amount,
    x="City",
    y="Final Amount"
)

plt.xlabel("City")
plt.ylabel("Average Final Amount")
plt.title("Average Final Amount by City")
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/user/Downloads/Hotel_booking_dataset - Hotel_booking_dataset.csv")

df["Room Type"] = (
    df["Room Type"].astype(str)
    .str.strip()
    .str.lower()
    .replace({
        "delux": "Deluxe",
        "deluxe": "Deluxe",
        "standard": "Standard",
        "suite": "Suite",
        "exec": "Executive",
        "executive": "Executive"
    })
)

df["Room Rate"] = (
    df["Room Rate"].astype(str)
    .str.replace("$", "", regex=False)
    .str.replace(",", "", regex=False)
    .str.replace("INR", "", regex=False)
    .str.strip()
)

df["Room Rate"] = pd.to_numeric(
    df["Room Rate"],
    errors="coerce"
)

plt.figure(figsize=(9, 5))
sns.boxplot(
    data=df,
    x="Room Type",
    y="Room Rate"
)

plt.xlabel("Room Type")
plt.ylabel("Room Rate")
plt.title("Room Rate Distribution by Room Type")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/user/Downloads/Hotel_booking_dataset - Hotel_booking_dataset.csv")

df["Booking Channel"] = (
    df["Booking Channel"].astype(str)
    .str.strip()
    .str.lower()
    .replace({
        "online": "Online",
        "walk-in": "Walk-in",
        "walk in": "Walk-in",
        "travel agent": "Travel Agent",
        "travelagent": "Travel Agent",
        "corp": "Corporate",
        "corporate": "Corporate"
    })
)

plt.figure(figsize=(8, 5))
sns.countplot(
    data=df,
    x="Booking Channel"
)

plt.xlabel("Booking Channel")
plt.ylabel("Number of Bookings")
plt.title("Bookings by Booking Channel")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/user/Downloads/Hotel_booking_dataset - Hotel_booking_dataset.csv")

df["Room Nights"] = (
    df["Room Nights"].astype(str)
    .str.extract(r"(\d+)", expand=False)
)

df["Room Nights"] = pd.to_numeric(
    df["Room Nights"],
    errors="coerce"
)

df.loc[df["Room Nights"] > 30, "Room Nights"] = pd.NA

plt.figure(figsize=(8, 5))
plt.hist(
    df["Room Nights"].dropna(),
    bins=10
)

plt.xlabel("Room Nights")
plt.ylabel("Number of Bookings")
plt.title("Distribution of Room Nights")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/user/Downloads/Hotel_booking_dataset - Hotel_booking_dataset.csv")

df["Customer Segment"] = (
    df["Customer Segment"].astype(str)
    .str.strip()
    .str.lower()
    .replace({
        "budget": "Budget",
        "regular": "Regular",
        "reg": "Regular",
        "premium": "Premium",
        "corporate": "Corporate",
        "vip": "VIP"
    })
)

df["Cancelled"] = (
    df["Cancelled"].astype(str)
    .str.strip()
    .str.lower()
    .replace({
        "yes": 1,
        "y": 1,
        "1": 1,
        "no": 0,
        "n": 0,
        "0": 0
    })
)

df["Cancelled"] = pd.to_numeric(
    df["Cancelled"],
    errors="coerce"
)

cancellation_rate = (
    df.groupby("Customer Segment")["Cancelled"]
    .mean()
    .mul(100)
    .reset_index()
)

plt.figure(figsize=(9, 5))
sns.barplot(
    data=cancellation_rate,
    x="Customer Segment",
    y="Cancelled"
)

plt.xlabel("Customer Segment")
plt.ylabel("Cancellation Rate (%)")
plt.title("Cancellation Rate by Customer Segment")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/user/Downloads/Hotel_booking_dataset - Hotel_booking_dataset.csv")

df["Gender"] = (
    df["Gender"].astype(str)
    .str.strip()
    .str.lower()
    .replace({
        "male": "Male",
        "m": "Male",
        "female": "Female",
        "f": "Female",
        "other": "Other"
    })
)

df["Age"] = (
    df["Age"].astype(str)
    .str.extract(r"(\d+)", expand=False)
)

df["Age"] = pd.to_numeric(
    df["Age"],
    errors="coerce"
)

df.loc[
    (df["Age"] < 18) | (df["Age"] > 90),
    "Age"
] = pd.NA

plt.figure(figsize=(8, 5))
sns.boxplot(
    data=df,
    x="Gender",
    y="Age"
)

plt.xlabel("Gender")
plt.ylabel("Age")
plt.title("Age Distribution by Gender")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/user/Downloads/Hotel_booking_dataset - Hotel_booking_dataset.csv")

df["Payment Method"] = (
    df["Payment Method"].astype(str)
    .str.strip()
    .str.lower()
    .replace({
        "credit card": "Credit Card",
        "debit card": "Debit Card",
        "upi": "UPI",
        "net banking": "Net Banking",
        "netbanking": "Net Banking",
        "cash": "Cash"
    })
)

plt.figure(figsize=(8, 5))
sns.countplot(
    data=df,
    x="Payment Method"
)

plt.xlabel("Payment Method")
plt.ylabel("Number of Bookings")
plt.title("Bookings by Payment Method")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/user/Downloads/Hotel_booking_dataset - Hotel_booking_dataset.csv")

df["Room Rate"] = (
    df["Room Rate"].astype(str)
    .str.replace("$", "", regex=False)
    .str.replace(",", "", regex=False)
    .str.replace("INR", "", regex=False)
)

df["Room Rate"] = pd.to_numeric(
    df["Room Rate"],
    errors="coerce"
)

df["Final Amount"] = pd.to_numeric(
    df["Final Amount"],
    errors="coerce"
)

plt.figure(figsize=(8, 5))
sns.scatterplot(
    data=df,
    x="Room Rate",
    y="Final Amount"
)

plt.xlabel("Room Rate")
plt.ylabel("Final Amount")
plt.title("Room Rate vs Final Amount")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/user/Downloads/Hotel_booking_dataset - Hotel_booking_dataset.csv")

df["Room Type"] = (
    df["Room Type"].astype(str)
    .str.strip()
    .str.lower()
    .replace({
        "delux": "Deluxe",
        "deluxe": "Deluxe",
        "standard": "Standard",
        "suite": "Suite",
        "exec": "Executive",
        "executive": "Executive"
    })
)

df["Final Amount"] = pd.to_numeric(
    df["Final Amount"],
    errors="coerce"
)

plt.figure(figsize=(9, 5))
sns.violinplot(
    data=df,
    x="Room Type",
    y="Final Amount"
)

plt.xlabel("Room Type")
plt.ylabel("Final Amount")
plt.title("Final Amount Distribution by Room Type")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/user/Downloads/Hotel_booking_dataset - Hotel_booking_dataset.csv")

df["Booking Channel"] = (
    df["Booking Channel"].astype(str)
    .str.strip()
    .str.lower()
    .replace({
        "online": "Online",
        "walk-in": "Walk-in",
        "walk in": "Walk-in",
        "travel agent": "Travel Agent",
        "travelagent": "Travel Agent",
        "corp": "Corporate",
        "corporate": "Corporate"
    })
)

df["Discount %"] = (
    df["Discount %"].astype(str)
    .str.replace("%", "", regex=False)
)

df["Discount %"] = pd.to_numeric(
    df["Discount %"],
    errors="coerce"
)

df.loc[
    (df["Discount %"] < 0) |
    (df["Discount %"] > 100),
    "Discount %"
] = pd.NA

avg_discount = (
    df.groupby("Booking Channel")["Discount %"]
    .mean()
    .reset_index()
)

plt.figure(figsize=(9, 5))
sns.barplot(
    data=avg_discount,
    x="Booking Channel",
    y="Discount %"
)

plt.xlabel("Booking Channel")
plt.ylabel("Average Discount (%)")
plt.title("Average Discount by Booking Channel")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/user/Downloads/Hotel_booking_dataset - Hotel_booking_dataset.csv")

df["Rating"] = (
    df["Rating"].astype(str)
    .str.extract(r"(\d+(?:\.\d+)?)", expand=False)
)

df["Rating"] = pd.to_numeric(
    df["Rating"],
    errors="coerce"
)

df.loc[
    (df["Rating"] < 1) |
    (df["Rating"] > 5),
    "Rating"
] = pd.NA

plt.figure(figsize=(8, 5))
plt.hist(
    df["Rating"].dropna(),
    bins=5
)

plt.xlabel("Rating")
plt.ylabel("Number of Customers")
plt.title("Distribution of Customer Ratings")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/user/Downloads/Hotel_booking_dataset - Hotel_booking_dataset.csv")

df["Is Member"] = (
    df["Is Member"].astype(str)
    .str.strip()
    .str.lower()
    .replace({
        "1": "Yes",
        "y": "Yes",
        "yes": "Yes",
        "member": "Yes",
        "0": "No",
        "n": "No",
        "no": "No"
    })
)

plt.figure(figsize=(7, 5))
sns.countplot(
    data=df,
    x="Is Member"
)

plt.xlabel("Is Member")
plt.ylabel("Number of Customers")
plt.title("Member vs Non-Member Customers")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/user/Downloads/Hotel_booking_dataset - Hotel_booking_dataset.csv")

df["City"] = (
    df["City"].astype(str)
    .str.strip()
    .str.title()
)

df["City"] = df["City"].replace({
    "Hydrabad": "Hyderabad",
    "Bangalore": "Bengaluru"
})

df["Profit"] = pd.to_numeric(
    df["Profit"],
    errors="coerce"
)

plt.figure(figsize=(10, 5))
sns.boxplot(
    data=df,
    x="City",
    y="Profit"
)

plt.xlabel("City")
plt.ylabel("Profit")
plt.title("Profit Distribution by City")
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/user/Downloads/Hotel_booking_dataset - Hotel_booking_dataset.csv")

df["Room Type"] = (
    df["Room Type"].astype(str)
    .str.strip()
    .str.lower()
    .replace({
        "delux": "Deluxe",
        "deluxe": "Deluxe",
        "standard": "Standard",
        "suite": "Suite",
        "exec": "Executive",
        "executive": "Executive"
    })
)

df["Guests"] = pd.to_numeric(
    df["Guests"],
    errors="coerce"
)

df.loc[
    df["Guests"] > 10,
    "Guests"
] = pd.NA

avg_guests = (
    df.groupby("Room Type")["Guests"]
    .mean()
    .reset_index()
)

plt.figure(figsize=(9, 5))
sns.barplot(
    data=avg_guests,
    x="Room Type",
    y="Guests"
)

plt.xlabel("Room Type")
plt.ylabel("Average Number of Guests")
plt.title("Average Guests by Room Type")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/user/Downloads/Hotel_booking_dataset - Hotel_booking_dataset.csv")

df["Age"] = (
    df["Age"].astype(str)
    .str.extract(r"(\d+)", expand=False)
)

df["Age"] = pd.to_numeric(
    df["Age"],
    errors="coerce"
)

df.loc[
    (df["Age"] < 18) |
    (df["Age"] > 90),
    "Age"
] = pd.NA

plt.figure(figsize=(8, 5))
sns.kdeplot(
    data=df,
    x="Age",
    fill=True
)

plt.xlabel("Age")
plt.ylabel("Density")
plt.title("Age Distribution - KDE Plot")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/user/Downloads/Hotel_booking_dataset - Hotel_booking_dataset.csv")

numeric_columns = [
    "Age",
    "Room Nights",
    "Room Rate",
    "Discount %",
    "Rating",
    "Guests",
    "Gross Amount",
    "Discount Amount",
    "Final Amount",
    "Profit"
]

for col in numeric_columns:
    df[col] = pd.to_numeric(
        df[col],
        errors="coerce"
    )

correlation = df[numeric_columns].corr()

plt.figure(figsize=(12, 8))
sns.heatmap(
    correlation,
    annot=True,
    fmt=".2f"
)

plt.title("Correlation Heatmap of Numeric Columns")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/user/Downloads/Hotel_booking_dataset - Hotel_booking_dataset.csv")

df["Gender"] = (
    df["Gender"].astype(str)
    .str.strip()
    .str.lower()
    .replace({
        "male": "Male",
        "m": "Male",
        "female": "Female",
        "f": "Female",
        "other": "Other"
    })
)

df["Customer Segment"] = (
    df["Customer Segment"].astype(str)
    .str.strip()
    .str.lower()
    .replace({
        "budget": "Budget",
        "regular": "Regular",
        "reg": "Regular",
        "premium": "Premium",
        "corporate": "Corporate",
        "vip": "VIP"
    })
)

plt.figure(figsize=(10, 5))
sns.countplot(
    data=df,
    x="Gender",
    hue="Customer Segment"
)

plt.xlabel("Gender")
plt.ylabel("Number of Customers")
plt.title("Gender Distribution by Customer Segment")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/user/Downloads/Hotel_booking_dataset - Hotel_booking_dataset.csv")

df["Booking Date"] = pd.to_datetime(
    df["Booking Date"],
    errors="coerce",
    dayfirst=True
)

df["Gross Amount"] = pd.to_numeric(
    df["Gross Amount"],
    errors="coerce"
)

df["Month"] = df["Booking Date"].dt.month_name()

monthly_revenue = (
    df.groupby("Month")["Gross Amount"]
    .sum()
    .reset_index()
)

month_order = [
    "January", "February", "March",
    "April", "May", "June",
    "July", "August", "September",
    "October", "November", "December"
]

monthly_revenue["Month"] = pd.Categorical(
    monthly_revenue["Month"],
    categories=month_order,
    ordered=True
)

monthly_revenue = monthly_revenue.sort_values("Month")

plt.figure(figsize=(12, 5))
sns.barplot(
    data=monthly_revenue,
    x="Month",
    y="Gross Amount"
)

plt.xlabel("Month")
plt.ylabel("Total Gross Amount")
plt.title("Total Gross Amount by Month")
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/13/1yf32tnn7sxcttdzt3_x3jg80000gn/T/ipykernel_9015/2430846733.py:7: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df["Booking Date"] = pd.to_datetime(
